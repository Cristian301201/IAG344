# %% [markdown]
# # LIBRERIAS

# %%
import pandas as pd #pip install pandas

# %% [markdown]
# # Cargar Datos

# %%
df =pd.read_csv("./dataset.csv")
df.head(5)

# %%
df.describe()

# %%
df2 = pd.read_excel("./ejemplo.xlsx")
df2.head(5)
# Out:
#       Cedula    Nombre    Apellido  Cedula_Limpia      Nombre_Completo  \
# 0  1.55.7777  Apolomeo  Buenavista        1557777  Apolomeo Buenavista
# 1  75.54.666  Jerundio   Benavides        7554666   Jerundio Benavides
#
#    Unnamed: 5
# 0    44444444
# 1        7544
